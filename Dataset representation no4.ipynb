# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\acaps_data.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#    ID      COUNTRY  ISO ADMIN_LEVEL_NAME  PCODE REGION  \
# 0   1  Afghanistan  AFG              NaN    NaN   Asia
# 1   2  Afghanistan  AFG            Kabul    NaN   Asia
# 2   3  Afghanistan  AFG              NaN    NaN   Asia
# 3   4  Afghanistan  AFG              NaN    NaN   Asia
# 4   5  Afghanistan  AFG              NaN    NaN   Asia
#
#                        CATEGORY  \
# 0        Public health measures
# 1        Public health measures
# 2        Public health measures
# 3  Social and economic measures
# 4             Social distancing
#
#                                              MEASURE TARGETED_POP_GROUP  \
# 0  Health screenings in airports and border cross...                 No
# 1                Introduction of quarantine policies                 No
# 2                                Awareness campaigns                 No
# 3  Emergency administrative structures activated ...                 No
# ...

# %%
#Dataset 1.This dataset contains information about the measures implemented in each country according to dates 
#and the source if its from the lealth ministiry

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\acaps_dict.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#   Column Variable Name        Label   Format      Codes Missing Values  \
# 0      A            ID           ID  Numeric       none    Not allowed
# 1      B       COUNTRY      COUNTRY     Text       none    Not allowed
# 2      C           ISO          ISO     Text  iso3 code    Not allowed
# 3      D   ADMIN_LEVEL  ADMIN_LEVEL     Text       none          Blank
# 4      E         PCODE        PCODE     Text       none          Blank
#
#                           Comments
# 0   Progressive numbers of entries
# 1                           Manual
# 2  Automated VLOOKUP with iso code
# 3                     if necessary
# 4                     if necessary

# %%
#This dataset contains information about the type of the variables

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\oxford.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#             CountryName CountryCode      Date  S1_School closing  \
# 0           Afghanistan         AFG  20200101                0.0
# 1                Angola         AGO  20200101                0.0
# 2  United Arab Emirates         ARE  20200101                NaN
# 3             Argentina         ARG  20200101                0.0
# 4               Armenia         ARM  20200101                NaN
#
#    S1_IsGeneral                                           S1_Notes  \
# 0           1.0  https://en.unesco.org/themes/education-emergen...
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
#
#    S2_Workplace closing  S2_IsGeneral S2_Notes  S3_Cancel public events  ...  \
# 0                   NaN           NaN      NaN                      0.0  ...
# ...

# %%
#Dataset 2. This dataset contains information about the measures in each country according to date
#also the confirmed cases and deaths
