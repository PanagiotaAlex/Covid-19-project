# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\covid_19.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Confirmed  Deaths  \
# 0            NaN    Afghanistan  33.0000  65.0000  1/22/20          0       0
# 1            NaN        Albania  41.1533  20.1683  1/22/20          0       0
# 2            NaN        Algeria  28.0339   1.6596  1/22/20          0       0
# 3            NaN        Andorra  42.5063   1.5218  1/22/20          0       0
# 4            NaN         Angola -11.2027  17.8739  1/22/20          0       0
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.shape
# Out:
# (25152, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of                   Province/State         Country/Region        Lat       Long  \
# 0                            NaN            Afghanistan  33.000000  65.000000
# 1                            NaN                Albania  41.153300  20.168300
# 2                            NaN                Algeria  28.033900   1.659600
# 3                            NaN                Andorra  42.506300   1.521800
# 4                            NaN                 Angola -11.202700  17.873900
# ...                          ...                    ...        ...        ...
# 25147  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 25148                        NaN            South Sudan   6.877000  31.307000
# 25149                        NaN         Western Sahara  24.215500 -12.885800
# 25150                        NaN  Sao Tome and Principe   0.186360   6.613081
# 25151                        NaN                  Yemen  15.552727  48.516388
#
# ...

# %%
df.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# dtype: object

# %%
df.describe().T
# Out:
#              count         mean           std       min      25%        50%  \
# Lat        25152.0    21.433571     24.740912  -51.7963   7.0000  23.659750
# Long       25152.0    22.597991     70.570899 -135.0000 -19.0208  20.921188
# Confirmed  25152.0  2430.562420  23545.664313   -1.0000   0.0000   6.000000
# Deaths     25152.0   147.948752   1561.525918   -1.0000   0.0000   0.000000
# Recovered  25152.0   607.899531   5210.234488    0.0000   0.0000   0.000000
#
#                 75%          max
# Lat         41.2044      71.7069
# Long        81.0000     178.0650
# Confirmed  184.0000  965785.0000
# Deaths       2.0000   54881.0000
# Recovered   18.0000  117727.0000

# %%
df.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# dtype: object

# %%
# We need to change the objects to categorical type
df.Province/State = pd.Categorical(df.Province/State)
df.Country/Region = pd.Categorical(df.Country/Region)
df.Date = pd.Categorical(df.Date)
# Out:
#   File "<ipython-input-11-4b816dbb67d8>", line 2
#     df.Province/State = pd.Categorical(df.Province/State)
#                                                          ^
# SyntaxError: can't assign to operator

# %%
df.rename(columns={"Province/State": "Province_State", "Country/Region": "Country_Region"})
# Out:
#                   Province_State         Country_Region        Lat       Long  \
# 0                            NaN            Afghanistan  33.000000  65.000000
# 1                            NaN                Albania  41.153300  20.168300
# 2                            NaN                Algeria  28.033900   1.659600
# 3                            NaN                Andorra  42.506300   1.521800
# 4                            NaN                 Angola -11.202700  17.873900
# ...                          ...                    ...        ...        ...
# 25147  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 25148                        NaN            South Sudan   6.877000  31.307000
# 25149                        NaN         Western Sahara  24.215500 -12.885800
# 25150                        NaN  Sao Tome and Principe   0.186360   6.613081
# 25151                        NaN                  Yemen  15.552727  48.516388
#
# ...

# %%
# We need to change the objects to categorical type
df.Province_State = pd.Categorical(df.Province_State)
df.Country_Region = pd.Categorical(df.Country_Region)
df.Date = pd.Categorical(df.Date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-916c2d8d8064> in <module>
#       1 # We need to change the objects to categorical type
# ----> 2 df.Province_State = pd.Categorical(df.Province_State)
#       3 df.Country_Region = pd.Categorical(df.Country_Region)
#       4 df.Date = pd.Categorical(df.Date)
#
# ~\Miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Province_State'

# %%
df.Date = pd.Categorical(df.Date)

# %%
df.dtypes
# Out:
# Province/State      object
# Country/Region      object
# Lat                float64
# Long               float64
# Date              category
# Confirmed            int64
# Deaths               int64
# Recovered            int64
# dtype: object

# %%
categorical_df = df.select_dtypes(include = ['category'])

# %%
categorical_df.head()
# Out:
#       Date
# 0  1/22/20
# 1  1/22/20
# 2  1/22/20
# 3  1/22/20
# 4  1/22/20

# %%
from pandas.api.types import CategoricalDtype
categorical_df = categorical_df.astype(CategoricalDtype(ordered = True))

# %%
categorical_df.head()
# Out:
#       Date
# 0  1/22/20
# 1  1/22/20
# 2  1/22/20
# 3  1/22/20
# 4  1/22/20

# %%
categorical_df.dtypes
# Out:
# Date    category
# dtype: object

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Confirmed  Deaths  \
# 0            NaN    Afghanistan  33.0000  65.0000  1/22/20          0       0
# 1            NaN        Albania  41.1533  20.1683  1/22/20          0       0
# 2            NaN        Algeria  28.0339   1.6596  1/22/20          0       0
# 3            NaN        Andorra  42.5063   1.5218  1/22/20          0       0
# 4            NaN         Angola -11.2027  17.8739  1/22/20          0       0
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.head(25152)
# Out:
#                   Province/State         Country/Region        Lat       Long  \
# 0                            NaN            Afghanistan  33.000000  65.000000
# 1                            NaN                Albania  41.153300  20.168300
# 2                            NaN                Algeria  28.033900   1.659600
# 3                            NaN                Andorra  42.506300   1.521800
# 4                            NaN                 Angola -11.202700  17.873900
# ...                          ...                    ...        ...        ...
# 25147  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 25148                        NaN            South Sudan   6.877000  31.307000
# 25149                        NaN         Western Sahara  24.215500 -12.885800
# 25150                        NaN  Sao Tome and Principe   0.186360   6.613081
# 25151                        NaN                  Yemen  15.552727  48.516388
#
# ...
