# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\GlobalTemperatures.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN

# %%
#1.Dataset that contains details about the average temperature in land, max and min and land and ocean 
#average temperature in differet dates

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\GlobalLandTemperaturesByMajorCity.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude
# 0  Côte D'Ivoire    5.63N     3.23W
# 1  Côte D'Ivoire    5.63N     3.23W
# 2  Côte D'Ivoire    5.63N     3.23W
# 3  Côte D'Ivoire    5.63N     3.23W
# 4  Côte D'Ivoire    5.63N     3.23W

# %%
#2.Dataset that contains details about the average temperature in different countries and cities
#as well as the latitude and longitude in different dates

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\GlobalLandTemperaturesByCountry.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
#3.Dataset that contains details about the average temperature in different countries in different dates

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\GlobalLandTemperaturesByState.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty State Country
# 0  1855-05-01              25.544                          1.171  Acre  Brazil
# 1  1855-06-01              24.228                          1.103  Acre  Brazil
# 2  1855-07-01              24.371                          1.044  Acre  Brazil
# 3  1855-08-01              25.427                          1.073  Acre  Brazil
# 4  1855-09-01              25.675                          1.014  Acre  Brazil

# %%
#4.Dataset that contains details about the average temperature in different countries in different dates

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\GlobalLandTemperaturesByCity.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
#5.Dataset that contains details about the average temperature in different countries and cities
#as well as the latitude and longitude in different dates

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\weather_week1.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#    Id Province/State Country/Region   Lat  Long        Date  ConfirmedCases  \
# 0   1            NaN    Afghanistan  33.0  65.0  2020-01-22             0.0
# 1   2            NaN    Afghanistan  33.0  65.0  2020-01-23             0.0
# 2   3            NaN    Afghanistan  33.0  65.0  2020-01-24             0.0
# 3   4            NaN    Afghanistan  33.0  65.0  2020-01-25             0.0
# 4   5            NaN    Afghanistan  33.0  65.0  2020-01-26             0.0
#
#    Fatalities  day_from_jan_first  temp   min   max    stp     slp  dewp  \
# 0         0.0                  22  42.6  33.6  54.9  999.9  1024.3  27.4
# 1         0.0                  23  42.0  32.7  55.9  999.9  1020.8  22.8
# 2         0.0                  24  40.1  36.9  43.2  999.9  1018.6  34.5
# 3         0.0                  25  46.0  37.9  56.3  999.9  1018.0  37.8
# 4         0.0                  26  42.8  36.1  53.1  999.9  1014.8  33.2
#
#          rh        ah  wdsp   prcp  fog
# 0  0.545709  0.186448   9.4   0.00    0
# 1  0.461259  0.163225  14.9  99.99    1
# 2  0.801794  0.325375  10.4   0.17    1
# 3  0.728175  0.214562   6.1   0.57    1
# 4  0.685513  0.231656  10.8   0.00    1

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\weather_week4.csv")                       
temperature_figures = data.copy()

# %%
temperature_figures.head()
# Out:
#    Id Country_Region Province_State        Date  ConfirmedCases  Fatalities  \
# 0   1    Afghanistan            NaN  2020-01-22             0.0         0.0
# 1   2    Afghanistan            NaN  2020-01-23             0.0         0.0
# 2   3    Afghanistan            NaN  2020-01-24             0.0         0.0
# 3   4    Afghanistan            NaN  2020-01-25             0.0         0.0
# 4   5    Afghanistan            NaN  2020-01-26             0.0         0.0
#
#   country+province   Lat  Long  day_from_jan_first  ...   min   max    stp  \
# 0     Afghanistan-  33.0  65.0                  22  ...  33.6  54.9  999.9
# 1     Afghanistan-  33.0  65.0                  23  ...  32.7  55.9  999.9
# 2     Afghanistan-  33.0  65.0                  24  ...  36.9  43.2  999.9
# 3     Afghanistan-  33.0  65.0                  25  ...  37.9  56.3  999.9
# 4     Afghanistan-  33.0  65.0                  26  ...  36.1  53.1  999.9
#
#       slp  dewp        rh        ah  wdsp   prcp  fog
# 0  1024.3  27.4  0.545709  0.186448   9.4   0.00    0
# 1  1020.8  22.8  0.461259  0.163225  14.9  99.99    1
# 2  1018.6  34.5  0.801794  0.325375  10.4   0.17    1
# 3  1018.0  37.8  0.728175  0.214562   6.1   0.57    1
# 4  1014.8  33.2  0.685513  0.231656  10.8   0.00    1
#
# [5 rows x 21 columns]

# %%
#Converting Temperature to celcius scale
temperature_figures['Temperature'] = (temperature_figures['temp']-32)*(5/9)
temperature_figures['Days since reported'] = temperature_figures['day_from_jan_first']-22

#Removing the not-important columns from the dataset.
temperature_figures.drop(['Id','Lat','Long','day_from_jan_first','wdsp', 'prcp','fog','min','max','temp'],axis=1,inplace=True)

#Viewing the datasert
temperature_figures.head()
# Out:
#   Country_Region Province_State        Date  ConfirmedCases  Fatalities  \
# 0    Afghanistan            NaN  2020-01-22             0.0         0.0
# 1    Afghanistan            NaN  2020-01-23             0.0         0.0
# 2    Afghanistan            NaN  2020-01-24             0.0         0.0
# 3    Afghanistan            NaN  2020-01-25             0.0         0.0
# 4    Afghanistan            NaN  2020-01-26             0.0         0.0
#
#   country+province    stp     slp  dewp        rh        ah  Temperature  \
# 0     Afghanistan-  999.9  1024.3  27.4  0.545709  0.186448     5.888889
# 1     Afghanistan-  999.9  1020.8  22.8  0.461259  0.163225     5.555556
# 2     Afghanistan-  999.9  1018.6  34.5  0.801794  0.325375     4.500000
# 3     Afghanistan-  999.9  1018.0  37.8  0.728175  0.214562     7.777778
# 4     Afghanistan-  999.9  1014.8  33.2  0.685513  0.231656     6.000000
#
#    Days since reported
# 0                    0
# 1                    1
# 2                    2
# 3                    3
# 4                    4

# %%
#until 24.03, until 08.04 the second data set
#Fatalities The number of confirmed cases in the area considered in the date considered
#day_from_jan_first The number of fatalitites in the area considered in the date considered

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\Afghanistan.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#          Date  State      Country  Cumulative_cases  Cumulative_death  \
# 0  22-01-2020    NaN  Afghanistan                 0                 0
# 1  23-01-2020    NaN  Afghanistan                 0                 0
# 2  24-01-2020    NaN  Afghanistan                 0                 0
# 3  25-01-2020    NaN  Afghanistan                 0                 0
# 4  26-01-2020    NaN  Afghanistan                 0                 0
#
#    Daily_cases  Daily_death  Latitude  Longitude  Temperature  ...  \
# 0            0            0        33         65         5.89  ...
# 1            0            0        33         65         5.56  ...
# 2            0            0        33         65         4.50  ...
# 3            0            0        33         65         7.78  ...
# 4            0            0        33         65         6.00  ...
#
#    Confirmed Cases/1000  Lung Patients (F)  Lung Patients (M)  \
# 0                   0.0              36.31              39.33
# 1                   0.0              36.31              39.33
# 2                   0.0              36.31              39.33
# 3                   0.0              36.31              39.33
# 4                   0.0              36.31              39.33
#
#    Median Age (Years)  Life Expectancy (M)  Life Expectancy (F)  \
# 0                18.4                 63.2                 63.6
# 1                18.4                 63.2                 63.6
# 2                18.4                 63.2                 63.6
# 3                18.4                 63.2                 63.6
# 4                18.4                 63.2                 63.6
#
#    Total_tests_conducted  Out_Travels (mill.)  In_travels(mill.)  \
# 0                   1019             1.561605       Not Reported
# 1                   1019             1.561605       Not Reported
# 2                   1019             1.561605       Not Reported
# 3                   1019             1.561605       Not Reported
# 4                   1019             1.561605       Not Reported
#
#    Domestic_Travels (mill.)
# 0              Not Reported
# 1              Not Reported
# 2              Not Reported
# 3              Not Reported
# 4              Not Reported
#
# [5 rows x 32 columns]

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\temperature_data.csv")                       
temperature_data = data.copy()

# %%
temperature_data.head()
# Out:
#          Date State      Country  Cumulative_cases  Cumulative_death  \
# 0  22-01-2020   NaN  Afghanistan                 0                 0
# 1  23-01-2020   NaN  Afghanistan                 0                 0
# 2  24-01-2020   NaN  Afghanistan                 0                 0
# 3  25-01-2020   NaN  Afghanistan                 0                 0
# 4  26-01-2020   NaN  Afghanistan                 0                 0
#
#    Daily_cases  Daily_death  Latitude  Longitude  Temperature  Wind_speed  \
# 0            0            0      33.0       65.0         5.89         9.4
# 1            0            0      33.0       65.0         5.56        14.9
# 2            0            0      33.0       65.0         4.50        10.4
# 3            0            0      33.0       65.0         7.78         6.1
# 4            0            0      33.0       65.0         6.00        10.8
#
#    Precipitation  Fog_Presence
# 0           0.00             0
# 1           0.00             1
# 2           0.17             1
# 3           0.57             1
# 4           0.00             1

# %%
data = pd.read_csv(r"C:\Users\user\OneDrive\Υπολογιστής\us-county.csv")                       
df = data.copy()

# %%
df.head()
# Out:
#    fips    state   county  Confirmed  Deaths    Smokers  Obesity  \
# 0  1001  Alabama  Autauga         19     1.0  18.081557     33.3
# 1  1003  Alabama  Baldwin         78     1.0  17.489033     31.0
# 2  1005  Alabama  Barbour         10     0.0  21.999985     41.7
# 3  1007  Alabama     Bibb         17     0.0  19.114200     37.6
# 4  1009  Alabama   Blount         15     0.0  19.208672     33.8
#
#    Food Environment index   Exercise  overcrowding  Diabetics  \
# 0                     7.2  69.130124      1.201923       11.1
# 1                     8.0  73.713549      1.270792       10.7
# 2                     5.6  53.166770      1.688596       17.6
# 3                     7.8  16.251364      0.255319       14.5
# 4                     8.4  15.634486      1.891368       17.0
#
#    Insufficient Sleep  Traffic Volume  65% Above Population  Rural Population
# 0           35.905406       88.457040             15.562670         42.002162
# 1           33.305868       86.997430             20.443350         42.279099
# 2           38.563167      102.291762             19.420441         67.789635
# 3           38.148865       29.335580             16.473214         68.352607
# 4           35.945010       33.411782             18.236515         89.951502
